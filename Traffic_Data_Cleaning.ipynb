# %%
from google.colab import drive
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/My Drive/Road_Traffic_Accidents/RTA Dataset.csv"

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
#check the dataset size
print("The data shape is:  ", df.shape)
# Out:
# The data shape is:   (12316, 32)

# %%
#Show columns names and data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
#checking for null values
null_values = df.isnull().sum()
print(null_values)
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
#checking for duplicate rows

duplicate_rows = df.duplicated().sum()
print(duplicate_rows)
# Out:
# 0

# %%
#checking for unique data

unique_data = df.nunique(dropna=True)
print(unique_data)
# Out:
# Time                           1074
# Day_of_week                       7
# Age_band_of_driver                5
# Sex_of_driver                     3
# Educational_level                 7
# Vehicle_driver_relation           4
# Driving_experience                7
# Type_of_vehicle                  17
# Owner_of_vehicle                  4
# Service_year_of_vehicle           6
# Defect_of_vehicle                 3
# Area_accident_occured            14
# Lanes_or_Medians                  7
# Road_allignment                   9
# Types_of_Junction                 8
# Road_surface_type                 5
# Road_surface_conditions           4
# Light_conditions                  4
# Weather_conditions                9
# Type_of_collision                10
# Number_of_vehicles_involved       6
# Number_of_casualties              8
# Vehicle_movement                 13
# Casualty_class                    4
# Sex_of_casualty                   3
# Age_band_of_casualty              6
# ...

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Number_of_vehicles_involved', 'Number_of_casualties', 'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity']

# %%
for index, coolumns_name in enumerate(column_names):
  print(index, coolumns_name)
# Out:
# 0 Time
# 1 Day_of_week
# 2 Age_band_of_driver
# 3 Sex_of_driver
# 4 Educational_level
# 5 Vehicle_driver_relation
# 6 Driving_experience
# 7 Type_of_vehicle
# 8 Owner_of_vehicle
# 9 Service_year_of_vehicle
# 10 Defect_of_vehicle
# 11 Area_accident_occured
# 12 Lanes_or_Medians
# 13 Road_allignment
# 14 Types_of_Junction
# 15 Road_surface_type
# 16 Road_surface_conditions
# 17 Light_conditions
# 18 Weather_conditions
# 19 Type_of_collision
# 20 Number_of_vehicles_involved
# 21 Number_of_casualties
# 22 Vehicle_movement
# 23 Casualty_class
# 24 Sex_of_casualty
# 25 Age_band_of_casualty
# 26 Casualty_severity
# 27 Work_of_casuality
# 28 Fitness_of_casuality
# 29 Pedestrian_movement
# 30 Cause_of_accident
# 31 Accident_severity

# %%
described_data = df.iloc[:,[20, 21]].describe()
print(described_data)
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
selected_columns = [
    'Educational_level', 'Defect_of_vehicle', 'Driving_experience',
    'Service_year_of_vehicle', 'Type_of_vehicle', 'Owner_of_vehicle',
    'Age_band_of_driver'
]
filtered_data = df[selected_columns]

filtered_data.to_csv('filtered_dataset.csv', index = False)

# %%
filtered_data.head()
# Out:
#     Educational_level Defect_of_vehicle Driving_experience  \
# 0   Above high school         No defect              1-2yr
# 1  Junior high school         No defect         Above 10yr
# 2  Junior high school         No defect              1-2yr
# 3  Junior high school         No defect             5-10yr
# 4  Junior high school         No defect              2-5yr
#
#   Service_year_of_vehicle      Type_of_vehicle Owner_of_vehicle  \
# 0              Above 10yr           Automobile            Owner
# 1                 5-10yrs  Public (> 45 seats)            Owner
# 2                     NaN      Lorry (41?100Q)            Owner
# 3                     NaN  Public (> 45 seats)     Governmental
# 4                 5-10yrs                  NaN            Owner
#
#   Age_band_of_driver
# 0              18-30
# 1              31-50
# 2              18-30
# 3              18-30
# 4              18-30

# %%
df = pd.read_csv('filtered_dataset.csv')
df.tail(20)
# Out:
#         Educational_level Defect_of_vehicle Driving_experience  \
# 12296  Junior high school         No defect              2-5yr
# 12297  Junior high school         No defect             5-10yr
# 12298  Junior high school         No defect         Above 10yr
# 12299   Elementary school         No defect              2-5yr
# 12300   Elementary school         No defect         Above 10yr
# 12301  Junior high school         No defect              1-2yr
# 12302  Junior high school         No defect             5-10yr
# 12303  Junior high school                 7              2-5yr
# 12304  Junior high school         No defect              2-5yr
# 12305  Junior high school         No defect              2-5yr
# 12306  Junior high school         No defect              2-5yr
# 12307  Junior high school         No defect         Above 10yr
# 12308  Junior high school         No defect         Above 10yr
# 12309   Elementary school         No defect             5-10yr
# ...

# %%
df.sample(20)
# Out:
#         Educational_level Defect_of_vehicle Driving_experience  \
# 12065   Elementary school         No defect             5-10yr
# 10728   Elementary school               NaN              1-2yr
# 11821   Elementary school         No defect             5-10yr
# 3246   Junior high school         No defect         Above 10yr
# 7061    Above high school         No defect         Above 10yr
# 11069   Elementary school         No defect              2-5yr
# 7108   Junior high school               NaN         Above 10yr
# 1994    Elementary school         No defect                NaN
# 6592   Junior high school         No defect         Above 10yr
# 1653   Junior high school         No defect              2-5yr
# 9398   Junior high school               NaN          Below 1yr
# 9358          High school               NaN         Above 10yr
# 2680          High school         No defect              2-5yr
# 4829   Junior high school               NaN         Above 10yr
# ...

# %%
Defect_of_vehicle = df['Defect_of_vehicle'].unique()
print(Defect_of_vehicle)
# Out:
# ['No defect' nan '7' '5']

# %%
defect_counts = df['Defect_of_vehicle'].value_counts()
print(defect_counts)
# Out:
# Defect_of_vehicle
# No defect    7777
# 7              76
# 5              36
# Name: count, dtype: int64

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Educational_level           741
# Defect_of_vehicle          4427
# Driving_experience          829
# Service_year_of_vehicle    3928
# Type_of_vehicle             950
# Owner_of_vehicle            482
# Age_band_of_driver            0
# dtype: int64

# %%
rows = df.shape[0]
print(rows)
# Out:
# 12316

# %%
from os import closerange
clean_data = df.dropna()
clean_data.to_csv('clean_dataset.csv', index = False)

# %%
df = pd.read_csv('clean_dataset.csv')
df.head()
# Out:
#     Educational_level Defect_of_vehicle Driving_experience  \
# 0   Above high school         No defect              1-2yr
# 1  Junior high school         No defect         Above 10yr
# 2  Junior high school         No defect              2-5yr
# 3  Junior high school         No defect         Above 10yr
# 4  Junior high school         No defect              1-2yr
#
#   Service_year_of_vehicle      Type_of_vehicle Owner_of_vehicle  \
# 0              Above 10yr           Automobile            Owner
# 1                 5-10yrs  Public (> 45 seats)            Owner
# 2              Above 10yr           Automobile     Governmental
# 3                   1-2yr      Lorry (41?100Q)            Owner
# 4                  2-5yrs           Automobile            Owner
#
#   Age_band_of_driver
# 0              18-30
# 1              31-50
# 2              18-30
# 3              18-30
# 4              18-30

# %%
df.shape[0]
# Out:
# 4759

# %%
df.tail(20)
# Out:
#        Educational_level Defect_of_vehicle Driving_experience  \
# 4739   Elementary school         No defect             5-10yr
# 4740  Junior high school         No defect             5-10yr
# 4741  Junior high school         No defect              1-2yr
# 4742  Junior high school         No defect              1-2yr
# 4743   Elementary school         No defect              2-5yr
# 4744  Junior high school         No defect          Below 1yr
# 4745  Junior high school         No defect              2-5yr
# 4746  Junior high school         No defect             5-10yr
# 4747  Junior high school         No defect         Above 10yr
# 4748   Elementary school         No defect              2-5yr
# 4749   Elementary school         No defect         Above 10yr
# 4750  Junior high school         No defect              1-2yr
# 4751  Junior high school         No defect             5-10yr
# 4752  Junior high school                 7              2-5yr
# ...

# %%
print(df.isnull().sum())
# Out:
# Educational_level          0
# Defect_of_vehicle          0
# Driving_experience         0
# Service_year_of_vehicle    0
# Type_of_vehicle            0
# Owner_of_vehicle           0
# Age_band_of_driver         0
# dtype: int64

# %%
df.sample(20)
# Out:
#        Educational_level Defect_of_vehicle Driving_experience  \
# 4232   Elementary school         No defect          Below 1yr
# 722   Junior high school         No defect             5-10yr
# 1309  Junior high school         No defect              1-2yr
# 2066         High school                 7              2-5yr
# 2825  Junior high school         No defect              1-2yr
# 1374  Junior high school         No defect          Below 1yr
# 2909  Junior high school         No defect             5-10yr
# 201   Junior high school         No defect          Below 1yr
# 1447   Elementary school         No defect              1-2yr
# 3184   Elementary school         No defect         Above 10yr
# 3245  Junior high school         No defect          Below 1yr
# 1514  Junior high school         No defect             5-10yr
# 1096  Junior high school         No defect          Below 1yr
# 4347  Junior high school         No defect              2-5yr
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Educational_level', hue='Defect_of_vehicle')
plt.title("Vehicle Defects by Educational Level")
plt.xticks(rotation=45)
plt.show()
